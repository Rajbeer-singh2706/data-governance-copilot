# %%
## RUN ALL 
## uv run pytest tests/ -v

# %%
# Run all tests with verbose output
## uv run pytest tests/ -v

# Run all tests with coverage report
## uv run pytest tests/ -v --cov=src --cov-report=term-missing

# Run a specific day's tests
## uv run pytest tests/test_day17.py -v

# Run tests matching a keyword
## uv run pytest tests/ -v -k "guardrail or cache"

# Run tests and stop on first failure
## uv run pytest tests/ -v -x

# Run all tests in parallel (if pytest-xdist is installed)
### uv run pytest tests/ -v -n auto

# Show slowest 10 tests
## uv run pytest tests/ -v --durations=10

# %%
#Your test files based on the project context are:
'''
tests/test_day13.py — guardrails, GPT-4o intent, hooks
tests/test_day14.py — LiteLLM fallback, Redis cache
tests/test_day15.py — retry logic, HITL
tests/test_day16.py — FastAPI endpoints, rate limiting, llm_guard
tests/test_day17.py — Teams bot, Adaptive Cards, HMAC
'''
