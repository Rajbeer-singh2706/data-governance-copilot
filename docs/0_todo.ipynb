# %%
############ TO DO ==> Project implementation #########
# 1. Nodes.py --> can keep prompts in some other directory ; PENDING
# 2. is streamlit production ready, if not what is production ready that we can take and replace the complete codebase in that
# 3. how to manage user authentctio and user session ?

# %%
########## Learning TO DO ###############
# 1. Notebook to learn/test checkpointer

# %% [markdown]
# ## Guardrails -- Queries ##

# %%
# Which guardrails api is usd in production?

# %%
## abh ##
'''
 ---> Data Product --> Bookings
'''

# Q) What are these (Bookings , Retention , CAC, LTV)
# Q) Can we get bookings data for last 6 months?
# RAW Layer 
# Silver Layer 
# Gold Layer 


## How our llm system fetch data from where?

## LTV
## CAC 
## REtention 

## Querstion 

### We need to make this project production ready 

## what are we are tryng to solve ?

## Problem Statement : 


## SuperVisorAgent
#Q) can we write product keywords somewhere else ?

# %%
## Add these in our implementation 
## How to make dashboard on langsmith call tracing ?

# %% [markdown]
# ## **Desiging-Chat1**

# %%
#Q1) why do u think is this tech stack is good to have in production ready application or do you think changes are required?
# 2. remove streamlit as it is not used in production?

# %% [markdown]
# ## **code-Chat**
