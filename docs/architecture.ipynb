# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## learn about these modules , with example
from dataclasses import dataclass, field
from typing import Optional
from dotenv import load_dotenv
# @dataclass

# %%
## Singleton — created once, imported everywhere

# %%
# Need to learn subscription Model any platform 
# almost all the platform are working on subscription model , that use case we can implemente

# %%
## Python Project : ecommerce , development
