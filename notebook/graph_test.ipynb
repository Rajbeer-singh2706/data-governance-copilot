# %% [markdown]
# # Graph End-to-End Test Notebook
#
# Use this notebook to invoke the compiled graph from `src/graph/graph.py` and verify the full workflow from supervisor routing through agent nodes, auto-ticket creation, and synthesizer output.
#
# The notebook passes the required checkpoint configuration keys so the graph can execute with the SQLite checkpointer used by this repo.

# %%
import sys
from pathlib import Path
from pprint import pprint

# Ensure repo root is on sys.path when running from src/graph_test.ipynb
notebook_dir = Path.cwd()
repo_root = notebook_dir.parent if notebook_dir.name == 'src' else notebook_dir
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from graph.graph import build_graph, copilot_graph
from graph.state import initial_state
from graph.routing import INTENT_AGENT_MAP

GRAPH = copilot_graph if 'copilot_graph' in globals() else build_graph()
GRAPH
# Out:
# PATH : data\memory.db
# checkpointer : <langgraph.checkpoint.sqlite.SqliteSaver object at 0x00000171F4D131A0>

# %%
def run_graph(query: str, time_range: str = 'last_month',
              data_products=None, thread_id: str = 'notebook_test',
              user_id: str = 'notebook_user'):
    state = initial_state(
        query=query,
        thread_id=thread_id,
        user_id=user_id,
        time_range=time_range,
    )
    if data_products is not None:
        state['data_products'] = data_products
    config = {'configurable': {'thread_id': thread_id}}
    final_state = GRAPH.invoke(state, config=config)
    return final_state

# %%
print('Repo root:', repo_root)
print('Graph compiled:', GRAPH is not None)
print('Intent routing map:')
for intent, agents in INTENT_AGENT_MAP.items():
    print(f' - {intent}: {agents}')
# Out:
# Repo root: d:\0_PROJECTS\data-governance-copilot
# Graph compiled: True
# Intent routing map:
#  - full_diagnostic: ['information', 'knowledge', 'metadata', 'capacity']
#  - data_quality: ['metadata', 'information']
#  - governance: ['metadata', 'knowledge']
#  - incident_review: ['capacity']
#  - knowledge_lookup: ['knowledge', 'metadata']
#  - metric_analysis: ['information', 'knowledge']
#  - write_ticket: ['capacity']
#  - write_metadata: ['metadata']
#  - write_rule: ['rule']
#  - unknown: ['information', 'knowledge']

# %%
# Change these values and rerun this cell to test different full-graph scenarios.
selected_query = 'Why did retention drop in the last month?'
selected_time_range = 'last_month'
selected_data_products = ['retention']
selected_thread_id = 'graph_test_01'
selected_user_id = 'notebook_user'


print('Selected query:', selected_query)
print('Selected time range:', selected_time_range)
print('Selected data products:', selected_data_products)
print('Selected thread id:', selected_thread_id)
print('Selected user id:', selected_user_id)
# Out:
# Selected query: Why did retention drop in the last month?
# Selected time range: last_month
# Selected data products: ['retention']
# Selected thread id: graph_test_01
# Selected user id: notebook_user

# %%
result = run_graph(
    selected_query,
    time_range=selected_time_range,
    data_products=selected_data_products,
    thread_id=selected_thread_id,
    user_id=selected_user_id,
)
# Out:
# q: why did retention drop in the last month?
# QueryIntent.WRITE_TICKET ['create ticket', 'create a bug', 'open bug', 'raise issue', 'log incident', 'file a ticket']
# QueryIntent.WRITE_METADATA ['update owner', 'set owner', 'update metadata', 'classify', 'update description']
# QueryIntent.WRITE_RULE ['create rule', 'add rule', 'define rule', 'new rule', 'create dq rule']
# QueryIntent.FULL_DIAGNOSTIC ['why did', 'root cause', 'investigate', 'explain why', 'diagnose', 'what happened']
# intent.value: full_diagnostic
# [16:35:58] INFO     agent.information_agent | [985501b3] information_agent received: 'Why did retention drop in the last month?'
# [16:35:58] INFO     agent.knowledge_agent | [985501b3] knowledge_agent received: 'Why did retention drop in the last month?'
# [16:35:58] INFO     agent.metadata_agent | [985501b3] metadata_agent received: 'Why did retention drop in the last month?'
# [16:35:58] INFO     agent.capacity_agent | [985501b3] capacity_agent received: 'Why did retention drop in the last month?'
# [16:35:58] INFO     agent.information_agent | [985501b3] information_agent done in 51.2ms
# [16:35:58] INFO     agent.metadata_agent | [985501b3] metadata_agent done in 38.09ms
# [16:35:58] INFO     agent.capacity_agent | [985501b3] capacity_agent done in 31.4ms
# [16:35:58] INFO     agent.knowledge_agent | [985501b3] knowledge_agent done in 54.8ms
# [16:35:58] INFO     agent.capacity_agent | [54910a29] capacity_agent received: 'create ticket for retention data quality issue'
# [16:35:58] INFO     agent.capacity_agent | [54910a29] capacity_agent done in 1.54ms
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print('--- Graph Result ---')
print('Final summary:')
print(result.get('final_summary'))
print('Confidence:', result.get('confidence'))
print('Next agents:', result.get('next_agents'))
print('Agent results count:', len(result.get('agent_results', [])))
print('Auto tickets:', result.get('auto_tickets'))
print('Sources:', result.get('sources'))
print('Execution ms:', result.get('execution_ms'))
print('--- Full state ---')
pprint(result)
# Out:
# --- Graph Result ---
# Final summary:
# 📊 **Metrics Summary** (last_month)
#
# **RETENTION**
#   • Gross Retention Rate: 83.22
#   • Gross Retention Prev: 87.3
#   • Net Retention Rate: 108.59
#   • Churn Rate: 16.78
#   • Churned Accounts: 19
#   • Total Accounts: 412
#   • At Risk Accounts: 24
#
# **🚨 Anomalies:**
#   ⚠️ GRR (83.22%) below 85% threshold — investigate churn drivers immediately.
#
# ---
#
# 📚 **Business Context**
#
# **RETENTION**
#   _Definition:_ Gross Retention Rate (GRR) measures the percentage of recurring revenue retained from existing customers, excluding expansion. Net Retention Rate (NRR) includes upsells. Benchmarks: GRR >85% (SMB), >90% (Enterprise).
#   _Context:_ Retention declines in Q3 2024 were attributed to: (1) product gaps in the reporting module cited in 34% of churn surveys, (2) competitive displacement by Vendor X in SMB, (3) a 2-week SLA breach in EU affecting 12 accounts.
#   _Reference:_ See: Retention Recovery Playbook v2.1 (SharePoint/CS/Playbooks/)
#
# ---
#
# 🏛️ **Governance & Metadata**
#
# **Gross Retention Rate** ✅
#   • Owner: Jane Smith (VP Customer Success)
#   • Steward: Data Governance Team
#   • Classifications: KPI, Confidential, PII-Free
#   • DQ Score: 🟡 72/100
#     ↳ Completeness:68 | Accuracy:81 | Timeliness:74
#   • Open DQ Issues (2):
#     🔴 [High] EU region data missing for 3 days (2024-09-12 to 2024-09-14)
#     🟡 [Medium] Discrepancy between CRM and DWH for 7 churned accounts
#   • Sources: Salesforce CRM, Zuora Billing
#   • Last Refresh: 2024-10-01T06:00:00Z
#   • Schedule: Daily 6:00 UTC
#
# ---
#
# 🎫 **Jira Issues & Operational Status**
#
# **RETENTION** — 2 open / 3 total
#   🔴 **DATA-4821** [Bug] 🔄 In Progress
#      EU region retention data missing — pipeline failure in Databricks job
#   🟡 **DATA-4890** [Bug] 🔴 Open
#      GRR/NRR discrepancy between Salesforce and Data Warehouse
#   🟡 **DATA-4712** [Story] ✅ Done
#      Add at-risk account segmentation to retention dashboard
#
# _Total open: 2_
# Confidence: 0.89
# Next agents: ['information', 'knowledge', 'metadata', 'capacity']
# Agent results count: 4
# Auto tickets: ['DATA-5973']
# Sources: ['[MOCK] analytics.retention_metrics', 'SharePoint: CS Strategy Deck Q3 2024', 'Collibra DGC: Gross Retention Rate', 'Jira (Mock): RETENTION']
# Execution ms: 0.0
# --- Full state ---
# {'agent_results': [{'agent': 'information_agent',
#                     'confidence': 0.85,
#                     'data': {'anomalies': ['⚠️ GRR (83.22%) below 85% '
#                                            'threshold — investigate churn '
#                                            'drivers immediately.'],
#                              'metrics': {'retention': {'at_risk_accounts': 24,
#                                                        'breakdown': {'Enterprise': 91.51,
#                                                                      'Mid-Market': 86.61,
#                                                                      'SMB': 76.53},
#                                                        'churn_rate': 16.78,
#                                                        'churned_accounts': 19,
#                                                        'gross_retention_prev': 87.3,
#                                                        'gross_retention_rate': 83.22,
#                                                        'net_retention_rate': 108.59,
#                                                        'time_range': 'last_month',
#                                                        'total_accounts': 412}}},
#                     'error': None,
#                     'execution_time_ms': 51.2,
#                     'metadata': {'products_queried': ['retention'],
#                                  'time_range': 'last_month'},
#                     'sources': ['[MOCK] analytics.retention_metrics'],
#                     'success': True,
#                     'summary': '📊 **Metrics Summary** (last_month)\n'
#                                '\n'
#                                '**RETENTION**\n'
#                                '  • Gross Retention Rate: 83.22\n'
#                                '  • Gross Retention Prev: 87.3\n'
#                                '  • Net Retention Rate: 108.59\n'
#                                '  • Churn Rate: 16.78\n'
#                                '  • Churned Accounts: 19\n'
#                                '  • Total Accounts: 412\n'
#                                '  • At Risk Accounts: 24\n'
#                                '\n'
#                                '**🚨 Anomalies:**\n'
#                                '  ⚠️ GRR (83.22%) below 85% threshold — '
#                                'investigate churn drivers immediately.',
#                     'timestamp': '2026-05-21T11:05:58.144460'},
#                    {'agent': 'knowledge_agent',
#                     'confidence': 0.88,
#                     'data': {'knowledge': [{'business_context': 'Retention '
#                                                                 'declines in '
#                                                                 'Q3 2024 were '
#                                                                 'attributed '
#                                                                 'to: (1) '
#                                                                 'product gaps '
#                                                                 'in the '
#                                                                 'reporting '
#                                                                 'module cited '
#                                                                 'in 34% of '
#                                                                 'churn '
#                                                                 'surveys, (2) '
#                                                                 'competitive '
#                                                                 'displacement '
#                                                                 'by Vendor X '
#                                                                 'in SMB, (3) a '
#                                                                 '2-week SLA '
#                                                                 'breach in EU '
#                                                                 'affecting 12 '
#                                                                 'accounts.',
#                                             'definition': 'Gross Retention '
#                                                           'Rate (GRR) measures '
#                                                           'the percentage of '
#                                                           'recurring revenue '
#                                                           'retained from '
#                                                           'existing customers, '
#                                                           'excluding '
#                                                           'expansion. Net '
#                                                           'Retention Rate '
#                                                           '(NRR) includes '
#                                                           'upsells. '
#                                                           'Benchmarks: GRR '
#                                                           '>85% (SMB), >90% '
#                                                           '(Enterprise).',
#                                             'runbook': 'See: Retention '
#                                                        'Recovery Playbook v2.1 '
#                                                        '(SharePoint/CS/Playbooks/)',
#                                             'source': 'SharePoint: CS Strategy '
#                                                       'Deck Q3 2024',
#                                             'topic': 'retention'}]},
#                     'error': None,
#                     'execution_time_ms': 54.8,
#                     'metadata': {'topics_found': ['retention']},
#                     'sources': ['SharePoint: CS Strategy Deck Q3 2024'],
#                     'success': True,
#                     'summary': '📚 **Business Context**\n'
#                                '\n'
#                                '**RETENTION**\n'
#                                '  _Definition:_ Gross Retention Rate (GRR) '
#                                'measures the percentage of recurring revenue '
#                                'retained from existing customers, excluding '
#                                'expansion. Net Retention Rate (NRR) includes '
#                                'upsells. Benchmarks: GRR >85% (SMB), >90% '
#                                '(Enterprise).\n'
#                                '  _Context:_ Retention declines in Q3 2024 '
#                                'were attributed to: (1) product gaps in the '
#                                'reporting module cited in 34% of churn '
#                                'surveys, (2) competitive displacement by '
#                                'Vendor X in SMB, (3) a 2-week SLA breach in EU '
#                                'affecting 12 accounts.\n'
#                                '  _Reference:_ See: Retention Recovery '
#                                'Playbook v2.1 (SharePoint/CS/Playbooks/)',
#                     'timestamp': '2026-05-21T11:05:58.158187'},
#                    {'agent': 'metadata_agent',
#                     'confidence': 0.93,
#                     'data': {'retention': {'asset_id': 'col-ret-001',
#                                            'asset_name': 'Gross Retention Rate',
#                                            'asset_type': 'Business Metric',
#                                            'certified': True,
#                                            'classification': ['KPI',
#                                                               'Confidential',
#                                                               'PII-Free'],
#                                            'data_quality': {'accuracy': 81,
#                                                             'completeness': 68,
#                                                             'consistency': 69,
#                                                             'issues': [{'description': 'EU '
#                                                                                        'region '
#                                                                                        'data '
#                                                                                        'missing '
#                                                                                        'for '
#                                                                                        '3 '
#                                                                                        'days '
#                                                                                        '(2024-09-12 '
#                                                                                        'to '
#                                                                                        '2024-09-14)',
#                                                                         'dimension': 'completeness',
#                                                                         'severity': 'High',
#                                                                         'status': 'Open'},
#                                                                        {'description': 'Discrepancy '
#                                                                                        'between '
#                                                                                        'CRM '
#                                                                                        'and '
#                                                                                        'DWH '
#                                                                                        'for '
#                                                                                        '7 '
#                                                                                        'churned '
#                                                                                        'accounts',
#                                                                         'dimension': 'consistency',
#                                                                         'severity': 'Medium',
#                                                                         'status': 'In '
#                                                                                   'Progress'}],
#                                                             'last_assessed': '2024-09-28',
#                                                             'overall_score': 72,
#                                                             'timeliness': 74,
#                                                             'uniqueness': 98,
#                                                             'validity': 77},
#                                            'domain': 'Customer Success',
#                                            'lineage': {'etl_pipeline': 'databricks_retention_pipeline_v3',
#                                                        'last_refresh': '2024-10-01T06:00:00Z',
#                                                        'refresh_schedule': 'Daily '
#                                                                            '6:00 '
#                                                                            'UTC',
#                                                        'source_systems': ['Salesforce '
#                                                                           'CRM',
#                                                                           'Zuora '
#                                                                           'Billing'],
#                                                        'target_tables': ['analytics.retention_metrics',
#                                                                          'marts.cs_kpis']},
#                                            'owner': 'Jane Smith (VP Customer '
#                                                     'Success)',
#                                            'status': 'Accepted',
#                                            'steward': 'Data Governance Team'}},
#                     'error': None,
#                     'execution_time_ms': 38.09,
#                     'metadata': {'overall_dq_score': 72.0,
#                                  'products': ['retention']},
#                     'sources': ['Collibra DGC: Gross Retention Rate'],
#                     'success': True,
#                     'summary': '🏛️ **Governance & Metadata**\n'
#                                '\n'
#                                '**Gross Retention Rate** ✅\n'
#                                '  • Owner: Jane Smith (VP Customer Success)\n'
#                                '  • Steward: Data Governance Team\n'
#                                '  • Classifications: KPI, Confidential, '
#                                'PII-Free\n'
#                                '  • DQ Score: 🟡 72/100\n'
#                                '    ↳ Completeness:68 | Accuracy:81 | '
#                                'Timeliness:74\n'
#                                '  • Open DQ Issues (2):\n'
#                                '    🔴 [High] EU region data missing for 3 days '
#                                '(2024-09-12 to 2024-09-14)\n'
#                                '    🟡 [Medium] Discrepancy between CRM and DWH '
#                                'for 7 churned accounts\n'
#                                '  • Sources: Salesforce CRM, Zuora Billing\n'
#                                '  • Last Refresh: 2024-10-01T06:00:00Z\n'
#                                '  • Schedule: Daily 6:00 UTC',
#                     'timestamp': '2026-05-21T11:05:58.151194'},
#                    {'agent': 'capacity_agent',
#                     'confidence': 0.9,
#                     'data': {'retention': [{'assignee': 'data-eng-eu@company.com',
#                                             'created': '2024-09-15T09:00:00Z',
#                                             'description': 'The '
#                                                            'retention_etl_eu '
#                                                            'job failed between '
#                                                            '2024-09-12 and '
#                                                            '2024-09-14 due to '
#                                                            'a schema change in '
#                                                            'the Salesforce '
#                                                            'source table. 3 '
#                                                            'days of EU data '
#                                                            'are missing.',
#                                             'id': 'DATA-4821',
#                                             'labels': ['data-quality',
#                                                        'retention',
#                                                        'etl-failure'],
#                                             'priority': 'High',
#                                             'status': 'In Progress',
#                                             'summary': 'EU region retention '
#                                                        'data missing — '
#                                                        'pipeline failure in '
#                                                        'Databricks job',
#                                             'type': 'Bug',
#                                             'updated': '2024-10-01T14:22:00Z'},
#                                            {'assignee': 'data-eng-core@company.com',
#                                             'created': '2024-09-28T11:30:00Z',
#                                             'description': '7 accounts show '
#                                                            'different churn '
#                                                            'status between CRM '
#                                                            'and DWH. Root '
#                                                            'cause: delayed '
#                                                            'Salesforce sync '
#                                                            'for multi-entity '
#                                                            'contracts.',
#                                             'id': 'DATA-4890',
#                                             'labels': ['data-quality',
#                                                        'retention',
#                                                        'crm-sync'],
#                                             'priority': 'Medium',
#                                             'status': 'Open',
#                                             'summary': 'GRR/NRR discrepancy '
#                                                        'between Salesforce and '
#                                                        'Data Warehouse',
#                                             'type': 'Bug',
#                                             'updated': '2024-09-30T09:15:00Z'},
#                                            {'assignee': 'data-eng-core@company.com',
#                                             'created': '2024-08-10T08:00:00Z',
#                                             'id': 'DATA-4712',
#                                             'labels': ['feature',
#                                                        'retention',
#                                                        'dashboard'],
#                                             'priority': 'Medium',
#                                             'status': 'Done',
#                                             'summary': 'Add at-risk account '
#                                                        'segmentation to '
#                                                        'retention dashboard',
#                                             'type': 'Story',
#                                             'updated': '2024-09-20T16:00:00Z'}]},
#                     'error': None,
#                     'execution_time_ms': 31.4,
#                     'metadata': {'open_issues': 2, 'products': ['retention']},
#                     'sources': ['Jira (Mock): RETENTION'],
#                     'success': True,
#                     'summary': '🎫 **Jira Issues & Operational Status**\n'
#                                '\n'
#                                '**RETENTION** — 2 open / 3 total\n'
#                                '  🔴 **DATA-4821** [Bug] 🔄 In Progress\n'
#                                '     EU region retention data missing — '
#                                'pipeline failure in Databricks job\n'
#                                '  🟡 **DATA-4890** [Bug] 🔴 Open\n'
#                                '     GRR/NRR discrepancy between Salesforce '
#                                'and Data Warehouse\n'
#                                '  🟡 **DATA-4712** [Story] ✅ Done\n'
#                                '     Add at-risk account segmentation to '
#                                'retention dashboard\n'
#                                '\n'
#                                '_Total open: 2_',
#                     'timestamp': '2026-05-21T11:05:58.152191'}],
#  'anomalies': ['⚠️ GRR (83.22%) below 85% threshold — investigate churn '
#                'drivers immediately.'],
#  'approved': False,
#  'auto_tickets': ['DATA-5973'],
#  'confidence': 0.89,
#  'conversation_history': [{'intent': 'full_diagnostic',
#                            'query': 'Why did retention drop in the last month?',
#                            'summary': '📊 **Metrics Summary** (last_month)\n'
#                                       '\n'
#                                       '**RETENTION**\n'
#                                       '  • Gross Retention Rate: 83.22\n'
#                                       '  • Gross Retention Prev: 87.3\n'
#                                       '  • Net Retention Rate: 108.59\n'
#                                       '  • Churn Rate: 16.78\n'
#                                       '  • Churned Accounts: 19\n'
#                                       '  • Total Accounts: 412\n'
#                                       '  • At Risk Accounts: 24\n'
#                                       '\n'
#                                       '**🚨 Anomalies:**\n'
#                                       '  ⚠️ GRR (83.22%) below 85% threshold — '
#                                       'investigate churn drivers immediately.\n'
#                                       '\n'
#                                       '---\n'
#                                       '\n'
#                                       '📚 **Business Context**\n'
#                                       '\n'
#                                       '**RETENTION**\n'
#                                       '  _Definition:_ Gross Retention Rate '
#                                       '(GRR) measures the percentage of '
#                                       'recurring revenue retained from '
#                                       'existing customer',
#                            'tickets': ['DATA-5973']}],
#  'data_products': ['retention'],
#  'errors': [],
#  'execution_ms': 0.0,
#  'final_summary': '📊 **Metrics Summary** (last_month)\n'
#                   '\n'
#                   '**RETENTION**\n'
#                   '  • Gross Retention Rate: 83.22\n'
#                   '  • Gross Retention Prev: 87.3\n'
#                   '  • Net Retention Rate: 108.59\n'
#                   '  • Churn Rate: 16.78\n'
#                   '  • Churned Accounts: 19\n'
#                   '  • Total Accounts: 412\n'
#                   '  • At Risk Accounts: 24\n'
#                   '\n'
#                   '**🚨 Anomalies:**\n'
#                   '  ⚠️ GRR (83.22%) below 85% threshold — investigate churn '
#                   'drivers immediately.\n'
#                   '\n'
#                   '---\n'
#                   '\n'
#                   '📚 **Business Context**\n'
#                   '\n'
#                   '**RETENTION**\n'
#                   '  _Definition:_ Gross Retention Rate (GRR) measures the '
#                   'percentage of recurring revenue retained from existing '
#                   'customers, excluding expansion. Net Retention Rate (NRR) '
#                   'includes upsells. Benchmarks: GRR >85% (SMB), >90% '
#                   '(Enterprise).\n'
#                   '  _Context:_ Retention declines in Q3 2024 were attributed '
#                   'to: (1) product gaps in the reporting module cited in 34% '
#                   'of churn surveys, (2) competitive displacement by Vendor X '
#                   'in SMB, (3) a 2-week SLA breach in EU affecting 12 '
#                   'accounts.\n'
#                   '  _Reference:_ See: Retention Recovery Playbook v2.1 '
#                   '(SharePoint/CS/Playbooks/)\n'
#                   '\n'
#                   '---\n'
#                   '\n'
#                   '🏛️ **Governance & Metadata**\n'
#                   '\n'
#                   '**Gross Retention Rate** ✅\n'
#                   '  • Owner: Jane Smith (VP Customer Success)\n'
#                   '  • Steward: Data Governance Team\n'
#                   '  • Classifications: KPI, Confidential, PII-Free\n'
#                   '  • DQ Score: 🟡 72/100\n'
#                   '    ↳ Completeness:68 | Accuracy:81 | Timeliness:74\n'
#                   '  • Open DQ Issues (2):\n'
#                   '    🔴 [High] EU region data missing for 3 days (2024-09-12 '
#                   'to 2024-09-14)\n'
#                   '    🟡 [Medium] Discrepancy between CRM and DWH for 7 '
#                   'churned accounts\n'
#                   '  • Sources: Salesforce CRM, Zuora Billing\n'
#                   '  • Last Refresh: 2024-10-01T06:00:00Z\n'
#                   '  • Schedule: Daily 6:00 UTC\n'
#                   '\n'
#                   '---\n'
#                   '\n'
#                   '🎫 **Jira Issues & Operational Status**\n'
#                   '\n'
#                   '**RETENTION** — 2 open / 3 total\n'
#                   '  🔴 **DATA-4821** [Bug] 🔄 In Progress\n'
#                   '     EU region retention data missing — pipeline failure in '
#                   'Databricks job\n'
#                   '  🟡 **DATA-4890** [Bug] 🔴 Open\n'
#                   '     GRR/NRR discrepancy between Salesforce and Data '
#                   'Warehouse\n'
#                   '  🟡 **DATA-4712** [Story] ✅ Done\n'
#                   '     Add at-risk account segmentation to retention '
#                   'dashboard\n'
#                   '\n'
#                   '_Total open: 2_',
#  'intent': 'full_diagnostic',
#  'next_agents': ['information', 'knowledge', 'metadata', 'capacity'],
#  'pending_action': None,
#  'query': 'Why did retention drop in the last month?',
#  'query_id': '985501b3',
#  'sources': ['[MOCK] analytics.retention_metrics',
#              'SharePoint: CS Strategy Deck Q3 2024',
#              'Collibra DGC: Gross Retention Rate',
#              'Jira (Mock): RETENTION'],
#  'thread_id': 'graph_test_01',
#  'time_range': 'last_month',
#  'user_id': 'notebook_user',
#  'user_preferences': {}}

# %% [markdown]
# ## Sample queries for targeted graph paths
#
# Use these query examples to exercise different agent combinations via the supervisor routing logic.
#
# - `Why did retention drop?` → full diagnostic (`information`, `knowledge`, `metadata`, `capacity`)
# - `Show governance metadata for retention` → governance path (`metadata`, `knowledge`)
# - `List open issues for retention` → incident review / capacity-only path
# - `What is GRR and why does it matter?` → knowledge lookup
# - `What is the current retention trend?` → metric analysis (`information`, `knowledge`)
# - `Create a rule for retention threshold` → rule path
# - `Create ticket for missing retention pipeline data` → write ticket path
#
# If the graph fails, verify that the `thread_id` in the config is provided and that the notebook is running from `src/graph_test.ipynb`.
