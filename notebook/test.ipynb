# %%
### Here we will keep all the phases, where we will test each codebase ( each Functionaly)
## for each functionality there should be detailed notebook

# %%
## 1. Functionality Test notebooks 
## 2. Codebase learning / testing notebook (for example --> test only redis)
